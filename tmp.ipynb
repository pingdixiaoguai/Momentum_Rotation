# %%
print((0.011111-0.065934))
print(85/90-1)
print(85/91-1)
print((85/90-1+85/91-1)/2)
print((85/(90+91)*2-1))
# Out:
# -0.05482300000000001
# -0.05555555555555558
# -0.06593406593406592
# -0.06074481074481075
# -0.06077348066298338

# %%
17.606875/13.149272-1
# Out:
# 0.3389999841816338
