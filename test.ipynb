# %%
from infra.repo import sync_latest_etf_data
from datetime import datetime

sync_latest_etf_data(codes=['513130'],beg_date=datetime(2025,10,8), end_date=datetime(2025,10,11))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from infra.repo import sync_latest_etf_data
#       2 from datetime import datetime
#       4 sync_latest_etf_data(codes=['513130'],beg_date=datetime(2025,10,8), end_date=datetime(2025,10,11))
#
# File E:\WorkSpace\Momentum_Rotation\infra\__init__.py:10
#       7 ROOT_DATA_DIR = Path(str(os.getenv("DATA_DIR")))
#       8 TICK_INTERVAL = float(os.getenv("TICK_INTERVAL", "0.2"))
# ---> 10 from .repo import (
#      11     sync_latest_industry_data,
#      12     sync_latest_etf_data,
#      13     sync_latest_index_data,
#      14     sync_latest_stock_data,
#      15     sync_latest_all_data,
#      16     get_latest_sync_date,
#      17     get_latest_trade_date,
#      18     find_last_trade_date
#      19 )
#      20 __all__ = ['sync_latest_industry_data','sync_latest_index_data','sync_latest_stock_data','sync_latest_all_data','get_latest_sync_date','get_latest_trade_date', 'find_last_trade_date','sync_latest_etf_data']
#
# File E:\WorkSpace\Momentum_Rotation\infra\repo.py:4
#       2 import time as time_module
#       3 import pandas as pd
# ----> 4 from utils import logger, Klt, DataType
#       5 from utils.const import *
#       6 from cachetools import TTLCache, cached
#
# File E:\WorkSpace\Momentum_Rotation\utils\__init__.py:8
#       4 from tenacity import Retrying,stop_after_attempt,wait_exponential,retry_if_exception_type,before_sleep_log
#       5 # from tenacity import RetryCallState
#       6
#       7 # 加载配置文件
# ----> 8 config.fileConfig('./logging.conf')
#      10 # 获取不同的日志记录器
#      11 logger = logging.getLogger('appLogger')
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.13-windows-x86_64-none\Lib\logging\config.py:90, in fileConfig(fname, defaults, disable_existing_loggers, encoding)
#      87     _clearExistingHandlers()
#      89     # Handlers add themselves to logging._handlers
# ---> 90     handlers = _install_handlers(cp, formatters)
#      91     _install_loggers(cp, handlers, disable_existing_loggers)
#      92 finally:
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.13-windows-x86_64-none\Lib\logging\config.py:156, in _install_handlers(cp, formatters)
#     154 kwargs = section.get("kwargs", '{}')
#     155 kwargs = eval(kwargs, vars(logging))
# --> 156 h = klass(*args, **kwargs)
#     157 h.name = hand
#     158 if "level" in section:
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.13-windows-x86_64-none\Lib\logging\__init__.py:1181, in FileHandler.__init__(self, filename, mode, encoding, delay, errors)
#    1179     self.stream = None
#    1180 else:
# -> 1181     StreamHandler.__init__(self, self._open())
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.13-windows-x86_64-none\Lib\logging\__init__.py:1213, in FileHandler._open(self)
#    1208 """
#    1209 Open the current base file with the (original) mode and encoding.
#    1210 Return the resulting stream.
#    1211 """
#    1212 open_func = self._builtin_open
# -> 1213 return open_func(self.baseFilename, self.mode,
#    1214                  encoding=self.encoding, errors=self.errors)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\WorkSpace\\Momentum_Rotation\\logs\\app-info.log'
